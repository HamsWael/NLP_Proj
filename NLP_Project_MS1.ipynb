# %% [markdown]
# <a href="https://colab.research.google.com/github/HamsWael/NLP_Proj/blob/main/NLP_Project_MS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import Libraries and Dataset**

# %%
import pandas as pd
import nltk
#used for tokenization
nltk.download('punkt')
from nltk.tokenize import word_tokenize
#used for lemmatization
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
#used for Stemming
from nltk.stem import PorterStemmer
#used for removing stopwords
nltk.download('stopwords')
from nltk.corpus import stopwords
#used for removing punctuations
import string
#used for POS Tagging
nltk.download('averaged_perceptron_tagger')
#used for visualizations
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.preprocessing import StandardScaler
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')
df3 = pd.read_csv('valid.csv')

# %%
df = pd.concat([df1, df2, df3], axis=0)

# %%
df
# Out:
#            Id                                              Title  \
# 0      197234  Drop\stop mobile data connection (non-wifi) by...
# 1      114800  How to automatically crop text messages when S...
# 2      124532        Can't find text message that was to a group
# 3      193875           Can't store contacts on my Android phone
# 4       50332  Dropbox on Samsung Galaxy - where is the Setti...
# ...       ...                                                ...
# 11003  218151  Disable vibrations for notifications on Xiaomi...
# 11004  102309                 Download and run Android APK files
# 11005   25096  Android apps keep crashing with android.databa...
# 11006  268441  Can you get viruses on iPhone from downloaded ...
# 11007  197968  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  Score  ViewCount  \
# 0      <p>Can I set Android 4.4.2 to drop mobile data...      0         34
# 1      <p>Is there a way to prevent the Messages app ...      0        836
# 2      <p>When John Doe texts to a group that include...      1         28
# 3      <p>I was going through all of my installed app...      0        158
# 4      <p>On a Sony Xperia, the settings button in Dr...      1        963
# ...                                                  ...    ...        ...
# 11003  <p>I have a Xiaomi Mi A3 on Android 9. I want ...      1        197
# 11004  <p>I want to download BitTorrent Sync to synch...      0        408
# 11005  <p>Starting yesterday, my Galaxy s2 device run...      8       3374
# 11006  <p>I downloaded an app for downloading things ...      1       1028
# 11007  <p>I am sending a bitly in SMS that masks an A...      0         46
#
#          Label  LabelNum
# 0      android         0
# 1      android         0
# 2      android         0
# 3      android         0
# 4      android         0
# ...        ...       ...
# 11003  android         0
# 11004  android         0
# 11005  android         0
# 11006      ios         1
# 11007  android         0
#
# [73386 rows x 7 columns]

# %% [markdown]
# ## **Data Inspection and Cleaning (Dropping Duplicates and Null Values)**

# %%
num_duplicates = df.duplicated().sum()
num_duplicates

#Therefore, no duplicates are found in this dataset
# Out:
# 0

# %%
df.isna().sum()
#No null values
# Out:
# Id           0
# Title        0
# Body         0
# Score        0
# ViewCount    0
# Label        0
# LabelNum     0
# dtype: int64

# %%
#Dropping unnecessary columns
#Drop ID column since its a unique identifier and would overfit/skew the model
df= df.drop('Id', axis=1)

# %%
#Dropping Label as we would have encoded it to what already exists in LabelNum Column
#0---> Android
#1---> ios
#Score and ViewCount also has nth to do with the question answering and classification
df= df.drop(['Score', 'ViewCount','Label'], axis=1)
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum
# 0      <p>Can I set Android 4.4.2 to drop mobile data...         0
# 1      <p>Is there a way to prevent the Messages app ...         0
# 2      <p>When John Doe texts to a group that include...         0
# 3      <p>I was going through all of my installed app...         0
# 4      <p>On a Sony Xperia, the settings button in Dr...         0
# ...                                                  ...       ...
# 11003  <p>I have a Xiaomi Mi A3 on Android 9. I want ...         0
# 11004  <p>I want to download BitTorrent Sync to synch...         0
# 11005  <p>Starting yesterday, my Galaxy s2 device run...         0
# 11006  <p>I downloaded an app for downloading things ...         1
# 11007  <p>I am sending a bitly in SMS that masks an A...         0
#
# [73386 rows x 3 columns]

# %%
df['Body'] = df['Body'].str.replace('<p>', '')
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum
# 0      Can I set Android 4.4.2 to drop mobile data co...         0
# 1      Is there a way to prevent the Messages app fro...         0
# 2      When John Doe texts to a group that includes m...         0
# 3      I was going through all of my installed applic...         0
# 4      On a Sony Xperia, the settings button in Dropb...         0
# ...                                                  ...       ...
# 11003  I have a Xiaomi Mi A3 on Android 9. I want to ...         0
# 11004  I want to download BitTorrent Sync to synchron...         0
# 11005  Starting yesterday, my Galaxy s2 device runnin...         0
# 11006  I downloaded an app for downloading things fro...         1
# 11007  I am sending a bitly in SMS that masks an Adob...         0
#
# [73386 rows x 3 columns]

# %% [markdown]
# ## **Data Analysis and Visualizations**

# %%
# Title Distribution of question lengths

df['Title'].str.len().hist()
# Out:
# <Axes: >

# %%
#The Below Count Plot shows that the dataset is imbalanced as it's obvious that android class is exceeding the ios by approximately 20,000 records.
# 0 = Android, 1 = IOS
sns.countplot(x='LabelNum', data=df)
plt.show()

# %% [markdown]
# ### **Below is the WordCloud to Visualize the Most frequent words in questions asked 'Title' regarding both classes: ios and Android respectively)**

# %%
tmp1= df[df['LabelNum']==1]
tmp1
# Out:
#                                                    Title  \
# 7      iPhone 5 iOS7 no sound only vibrates when ring...
# 9      Is this an iCloud sync/backup or do I have a d...
# 10              Ping command with parameters from iPhone
# 13       Transferring iPhone message history to new Mac?
# 24                  edit server in iphone exchange email
# ...                                                  ...
# 10981  Is there a way to force iPad to show a mobile ...
# 10982  Windows: Can I set the folder where iTunes bac...
# 10990                           Sky blue dot next to app
# 10995  How do I find out which folder an app is in in...
# 11006  Can you get viruses on iPhone from downloaded ...
#
#                                                     Body  LabelNum
# 7      Here is what I tried...</p>\n\n<ol>\n<li><code...         1
# 9      What are these pictures showing my iPhone's sc...         1
# 10     How I can execute ping command with parameter ...         1
# 13     My filesystem was corrupted when updating to H...         1
# 24     We used to use Mobile Iron to configure our us...         1
# ...                                                  ...       ...
# 10981  I'm trying to access an internal website to vi...         1
# 10982  I have a PC running Windows 10 with 2 Hard dri...         1
# 10990  I got an iPhone 7+ on iOS 10.2 and I just got ...         1
# 10995  In older versions of iOS, if I searched for an...         1
# 11006  I downloaded an app for downloading things fro...         1
#
# [20310 rows x 3 columns]

# %%
wc_txt = ' '.join(tmp1['Title'])


wordcloud = WordCloud(width = 800, height = 400, background_color ='white').generate(wc_txt)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('WordCloud for ios Titles')
plt.axis("off")
plt.show()

# %%
tmp2= df[df['LabelNum']==0]
wc_txt1 = ' '.join(tmp2['Title'])


wordcloud = WordCloud(width = 800, height = 400, background_color ='white').generate(wc_txt1)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('WordCloud for Android Titles')
plt.axis("off")
plt.show()

# %% [markdown]
# ## **Text Preprocessing**

# %%
#Tokenize the attributes "Title", "Body"
df['Title'] = df['Title'].apply(lambda x: word_tokenize(x))
df['Body'] = df['Body'].apply(lambda x: word_tokenize(x))
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum  \
# 0      Can I set Android 4.4.2 to drop mobile data co...         0
# 1      Is there a way to prevent the Messages app fro...         0
# 2      When John Doe texts to a group that includes m...         0
# 3      I was going through all of my installed applic...         0
# 4      On a Sony Xperia, the settings button in Dropb...         0
# ...                                                  ...       ...
# 11003  I have a Xiaomi Mi A3 on Android 9. I want to ...         0
# 11004  I want to download BitTorrent Sync to synchron...         0
# 11005  Starting yesterday, my Galaxy s2 device runnin...         0
# 11006  I downloaded an app for downloading things fro...         1
# 11007  I am sending a bitly in SMS that masks an Adob...         0
#
#                                       Title_Preprocessed  \
# 0      [Drop\stop, mobile, data, connection, (, non-w...
# 1      [How, to, automatically, crop, text, messages,...
# 2      [Ca, n't, find, text, message, that, was, to, ...
# 3      [Ca, n't, store, contacts, on, my, Android, ph...
# 4      [Dropbox, on, Samsung, Galaxy, -, where, is, t...
# ...                                                  ...
# 11003  [Disable, vibrations, for, notifications, on, ...
# 11004          [Download, and, run, Android, APK, files]
# 11005  [Android, apps, keep, crashing, with, android....
# 11006  [Can, you, get, viruses, on, iPhone, from, dow...
# 11007  [How, to, force, Adobe, tracking, link, in, SM...
#
#                                        Body_Preprocessed
# 0      [Can, I, set, Android, 4.4.2, to, drop, mobile...
# 1      [Is, there, a, way, to, prevent, the, Messages...
# 2      [When, John, Doe, texts, to, a, group, that, i...
# 3      [I, was, going, through, all, of, my, installe...
# 4      [On, a, Sony, Xperia, ,, the, settings, button...
# ...                                                  ...
# 11003  [I, have, a, Xiaomi, Mi, A3, on, Android, 9, ....
# 11004  [I, want, to, download, BitTorrent, Sync, to, ...
# 11005  [Starting, yesterday, ,, my, Galaxy, s2, devic...
# 11006  [I, downloaded, an, app, for, downloading, thi...
# 11007  [I, am, sending, a, bitly, in, SMS, that, mask...
#
# [73386 rows x 5 columns]

# %%
#Use Lemmatize the tokenized text to reduce words to their base form and takes into account the context.
lemmatizer = WordNetLemmatizer()
df['Title'] = df['Title'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
df['Body'] = df['Body'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum  \
# 0      Can I set Android 4.4.2 to drop mobile data co...         0
# 1      Is there a way to prevent the Messages app fro...         0
# 2      When John Doe texts to a group that includes m...         0
# 3      I was going through all of my installed applic...         0
# 4      On a Sony Xperia, the settings button in Dropb...         0
# ...                                                  ...       ...
# 11003  I have a Xiaomi Mi A3 on Android 9. I want to ...         0
# 11004  I want to download BitTorrent Sync to synchron...         0
# 11005  Starting yesterday, my Galaxy s2 device runnin...         0
# 11006  I downloaded an app for downloading things fro...         1
# 11007  I am sending a bitly in SMS that masks an Adob...         0
#
#                                       Title_Preprocessed  \
# 0      [Drop\stop, mobile, data, connection, (, non-w...
# 1      [How, to, automatically, crop, text, message, ...
# 2      [Ca, n't, find, text, message, that, wa, to, a...
# 3      [Ca, n't, store, contact, on, my, Android, phone]
# 4      [Dropbox, on, Samsung, Galaxy, -, where, is, t...
# ...                                                  ...
# 11003  [Disable, vibration, for, notification, on, Xi...
# 11004           [Download, and, run, Android, APK, file]
# 11005  [Android, apps, keep, crashing, with, android....
# 11006  [Can, you, get, virus, on, iPhone, from, downl...
# 11007  [How, to, force, Adobe, tracking, link, in, SM...
#
#                                        Body_Preprocessed
# 0      [Can, I, set, Android, 4.4.2, to, drop, mobile...
# 1      [Is, there, a, way, to, prevent, the, Messages...
# 2      [When, John, Doe, text, to, a, group, that, in...
# 3      [I, wa, going, through, all, of, my, installed...
# 4      [On, a, Sony, Xperia, ,, the, setting, button,...
# ...                                                  ...
# 11003  [I, have, a, Xiaomi, Mi, A3, on, Android, 9, ....
# 11004  [I, want, to, download, BitTorrent, Sync, to, ...
# 11005  [Starting, yesterday, ,, my, Galaxy, s2, devic...
# 11006  [I, downloaded, an, app, for, downloading, thi...
# 11007  [I, am, sending, a, bitly, in, SMS, that, mask...
#
# [73386 rows x 5 columns]

# %%
#remove stopwords such as  "a," "an," "the," "is," "and," "in"
stop_words = set(stopwords.words('english'))
df['Title'] = df['Title'].apply(lambda x: [word for word in x if word not in stop_words])
df['Body'] = df['Body'].apply(lambda x: [word for word in x if word not in stop_words])
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum  \
# 0      Can I set Android 4.4.2 to drop mobile data co...         0
# 1      Is there a way to prevent the Messages app fro...         0
# 2      When John Doe texts to a group that includes m...         0
# 3      I was going through all of my installed applic...         0
# 4      On a Sony Xperia, the settings button in Dropb...         0
# ...                                                  ...       ...
# 11003  I have a Xiaomi Mi A3 on Android 9. I want to ...         0
# 11004  I want to download BitTorrent Sync to synchron...         0
# 11005  Starting yesterday, my Galaxy s2 device runnin...         0
# 11006  I downloaded an app for downloading things fro...         1
# 11007  I am sending a bitly in SMS that masks an Adob...         0
#
#                                       Title_Preprocessed  \
# 0      [Drop\stop, mobile, data, connection, (, non-w...
# 1      [How, automatically, crop, text, message, SMS,...
# 2              [Ca, n't, find, text, message, wa, group]
# 3              [Ca, n't, store, contact, Android, phone]
# 4      [Dropbox, Samsung, Galaxy, -, Settings, button...
# ...                                                  ...
# 11003  [Disable, vibration, notification, Xiaomi, Mi,...
# 11004                [Download, run, Android, APK, file]
# 11005  [Android, apps, keep, crashing, android.databa...
# 11006      [Can, get, virus, iPhone, downloaded, app, ?]
# 11007  [How, force, Adobe, tracking, link, SMS, open,...
#
#                                        Body_Preprocessed
# 0      [Can, I, set, Android, 4.4.2, drop, mobile, da...
# 1      [Is, way, prevent, Messages, app, sending, lon...
# 2      [When, John, Doe, text, group, includes, ,, ap...
# 3      [I, wa, going, installed, application, phone, ...
# 4      [On, Sony, Xperia, ,, setting, button, Dropbox...
# ...                                                  ...
# 11003  [I, Xiaomi, Mi, A3, Android, 9, ., I, want, di...
# 11004  [I, want, download, BitTorrent, Sync, synchron...
# 11005  [Starting, yesterday, ,, Galaxy, s2, device, r...
# 11006  [I, downloaded, app, downloading, thing, inter...
# 11007  [I, sending, bitly, SMS, mask, Adobe, tracking...
#
# [73386 rows x 5 columns]

# %%
#remove punctuations
df['Title'] = df['Title'].apply(lambda x: [word for word in x if word not in string.punctuation])
df['Body'] = df['Body'].apply(lambda x: [word for word in x if word not in string.punctuation])
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum  \
# 0      Can I set Android 4.4.2 to drop mobile data co...         0
# 1      Is there a way to prevent the Messages app fro...         0
# 2      When John Doe texts to a group that includes m...         0
# 3      I was going through all of my installed applic...         0
# 4      On a Sony Xperia, the settings button in Dropb...         0
# ...                                                  ...       ...
# 11003  I have a Xiaomi Mi A3 on Android 9. I want to ...         0
# 11004  I want to download BitTorrent Sync to synchron...         0
# 11005  Starting yesterday, my Galaxy s2 device runnin...         0
# 11006  I downloaded an app for downloading things fro...         1
# 11007  I am sending a bitly in SMS that masks an Adob...         0
#
#                                       Title_Preprocessed  \
# 0      [Drop\stop, mobile, data, connection, non-wifi...
# 1      [How, automatically, crop, text, message, SMS,...
# 2              [Ca, n't, find, text, message, wa, group]
# 3              [Ca, n't, store, contact, Android, phone]
# 4           [Dropbox, Samsung, Galaxy, Settings, button]
# ...                                                  ...
# 11003  [Disable, vibration, notification, Xiaomi, Mi,...
# 11004                [Download, run, Android, APK, file]
# 11005  [Android, apps, keep, crashing, android.databa...
# 11006         [Can, get, virus, iPhone, downloaded, app]
# 11007  [How, force, Adobe, tracking, link, SMS, open,...
#
#                                        Body_Preprocessed
# 0      [Can, I, set, Android, 4.4.2, drop, mobile, da...
# 1      [Is, way, prevent, Messages, app, sending, lon...
# 2      [When, John, Doe, text, group, includes, appea...
# 3      [I, wa, going, installed, application, phone, ...
# 4      [On, Sony, Xperia, setting, button, Dropbox, t...
# ...                                                  ...
# 11003  [I, Xiaomi, Mi, A3, Android, 9, I, want, disab...
# 11004  [I, want, download, BitTorrent, Sync, synchron...
# 11005  [Starting, yesterday, Galaxy, s2, device, runn...
# 11006  [I, downloaded, app, downloading, thing, inter...
# 11007  [I, sending, bitly, SMS, mask, Adobe, tracking...
#
# [73386 rows x 5 columns]

# %%
#Apply lowercase
df['Title'] = df['Title'].apply(lambda x: [word.lower() for word in x])
df['Body'] = df['Body'].apply(lambda x: [word.lower() for word in x])
df
# Out:
#                                                    Title  \
# 0      Drop\stop mobile data connection (non-wifi) by...
# 1      How to automatically crop text messages when S...
# 2            Can't find text message that was to a group
# 3               Can't store contacts on my Android phone
# 4      Dropbox on Samsung Galaxy - where is the Setti...
# ...                                                  ...
# 11003  Disable vibrations for notifications on Xiaomi...
# 11004                 Download and run Android APK files
# 11005  Android apps keep crashing with android.databa...
# 11006  Can you get viruses on iPhone from downloaded ...
# 11007  How to force Adobe tracking link in SMS to ope...
#
#                                                     Body  LabelNum  \
# 0      Can I set Android 4.4.2 to drop mobile data co...         0
# 1      Is there a way to prevent the Messages app fro...         0
# 2      When John Doe texts to a group that includes m...         0
# 3      I was going through all of my installed applic...         0
# 4      On a Sony Xperia, the settings button in Dropb...         0
# ...                                                  ...       ...
# 11003  I have a Xiaomi Mi A3 on Android 9. I want to ...         0
# 11004  I want to download BitTorrent Sync to synchron...         0
# 11005  Starting yesterday, my Galaxy s2 device runnin...         0
# 11006  I downloaded an app for downloading things fro...         1
# 11007  I am sending a bitly in SMS that masks an Adob...         0
#
#                                       Title_Preprocessed  \
# 0      [drop\stop, mobile, data, connection, non-wifi...
# 1      [how, automatically, crop, text, message, sms,...
# 2              [ca, n't, find, text, message, wa, group]
# 3              [ca, n't, store, contact, android, phone]
# 4           [dropbox, samsung, galaxy, settings, button]
# ...                                                  ...
# 11003  [disable, vibration, notification, xiaomi, mi,...
# 11004                [download, run, android, apk, file]
# 11005  [android, apps, keep, crashing, android.databa...
# 11006         [can, get, virus, iphone, downloaded, app]
# 11007  [how, force, adobe, tracking, link, sms, open,...
#
#                                        Body_Preprocessed
# 0      [can, i, set, android, 4.4.2, drop, mobile, da...
# 1      [is, way, prevent, messages, app, sending, lon...
# 2      [when, john, doe, text, group, includes, appea...
# 3      [i, wa, going, installed, application, phone, ...
# 4      [on, sony, xperia, setting, button, dropbox, t...
# ...                                                  ...
# 11003  [i, xiaomi, mi, a3, android, 9, i, want, disab...
# 11004  [i, want, download, bittorrent, sync, synchron...
# 11005  [starting, yesterday, galaxy, s2, device, runn...
# 11006  [i, downloaded, app, downloading, thing, inter...
# 11007  [i, sending, bitly, sms, mask, adobe, tracking...
#
# [73386 rows x 5 columns]

# %% [markdown]
# ## **Insights Generated**
